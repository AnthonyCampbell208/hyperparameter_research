# %%
import pandas as pd
import pickle

file_path = "../ACIC_dataset/high_binary_datasets.pickle"

with open(file_path, "rb") as f:
    data = pickle.load(f)

# %%
pd.read_csv(data[0])
# Out:
#       Y  A  V1  V2  V3  V4  V5  V6  V7    V8  ...  V176  V177  V178  V179  \
# 0     1  1   1   1   4  18  15  -1   6  0.13  ...     8     8     8     8
# 1     0  0   1   1  17  11   9   2   7  0.06  ...     7     7     9     7
# 2     0  1   1   1   9  20   7  20   8 -0.14  ...    80   120    80    80
# 3     0  0   0   1   9  20  18  18  11  0.82  ...   -10   -10   -10   -10
# 4     0  0   0   1  14  18   2   2   8  0.15  ...    -1    -1    -1    -1
# ...  .. ..  ..  ..  ..  ..  ..  ..  ..   ...  ...   ...   ...   ...   ...
# 1995  0  0   0   1   2  16   7  -1   7 -0.33  ...     7     8     8     7
# 1996  1  0   0   1  21  22  17  17   4  0.00  ...    -1    -1    -1    -1
# 1997  0  0   0   1  14  18  17  17  17  0.04  ...     7     9     8     8
# 1998  1  1   1   1  15  18  16  12   5 -0.32  ...    -1    -1    -1    -1
# 1999  0  0   1   1  21  22  19   5  15 -0.21  ...    -1    -1    -1    -1
#
#       V180  V181  V182  V183  V184  V185
# ...
